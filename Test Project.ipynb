# %% [markdown]
# Cell 1: <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# Cell 2: <b>John</b><br>Teacher

# %% [markdown]
# Cell 3: <i>I am interested in data science because I have been tasked with teaching Data Science in a high school course. Also, I am a hobby statistician, data analyst, programmer. So this is fun to me.</i>

# %% [markdown]
# Cell 4: <h3>My code will print "Hello. My name is John."</h3>

# %%
name = "John"

print("My name is {}.".format(name))
# Out:
# My name is John.

# %% [markdown]
# Cell 6:#this cell must include at least 3 of the following:
# #horizontal rule, bulleted list, numbered list, tables,
# #hyperlinks, images, code/syntax highlighting, blocked quotes, strikethrough.
#
# #This bulleted list has good song titles.
# <ul><li>Peaceful Easy Feeling</li><li>Amarillo by Morning</li><li>The Gambler</li></ul>
#
# <hr>
#
# #this link is a great song!
# <a href="https://www.youtube.com/watch?v=wtVeDaZxAXo">Amarillo by Morning</a>
#
# <hr>
#
# #here is an image of a seashore
# <img src="https://image.shutterstock.com/image-photo/sandy-seashore-sunset-nature-landscape-260nw-1891082896.jpg"></img>
